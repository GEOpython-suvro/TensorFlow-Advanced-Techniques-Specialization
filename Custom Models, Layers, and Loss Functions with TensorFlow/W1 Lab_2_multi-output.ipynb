# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 884us/sample - loss: 269.6651 - y1_output_loss: 128.8280 - y2_output_loss: 138.3771 - y1_output_root_mean_squared_error: 11.4031 - y2_output_root_mean_squared_error: 11.8167 - val_loss: 38.7819 - val_y1_output_loss: 15.9494 - val_y2_output_loss: 21.5493 - val_y1_output_root_mean_squared_error: 4.0601 - val_y2_output_root_mean_squared_error: 4.7221
# Epoch 2/500
# 614/614 [==============================] - 0s 134us/sample - loss: 30.0790 - y1_output_loss: 12.2869 - y2_output_loss: 17.5770 - y1_output_root_mean_squared_error: 3.5207 - y2_output_root_mean_squared_error: 4.2052 - val_loss: 27.9608 - val_y1_output_loss: 11.8132 - val_y2_output_loss: 16.4433 - val_y1_output_root_mean_squared_error: 3.4087 - val_y2_output_root_mean_squared_error: 4.0425
# Epoch 3/500
# 614/614 [==============================] - 0s 140us/sample - loss: 25.7614 - y1_output_loss: 10.3947 - y2_output_loss: 15.3060 - y1_output_root_mean_squared_error: 3.2223 - y2_output_root_mean_squared_error: 3.9215 - val_loss: 23.1372 - val_y1_output_loss: 10.2842 - val_y2_output_loss: 13.4488 - val_y1_output_root_mean_squared_error: 3.1344 - val_y2_output_root_mean_squared_error: 3.6487
# Epoch 4/500
# 614/614 [==============================] - 0s 123us/sample - loss: 23.1794 - y1_output_loss: 9.5877 - y2_output_loss: 13.5753 - y1_output_root_mean_squared_error: 3.1010 - y2_output_root_mean_squared_error: 3.6828 - val_loss: 24.8007 - val_y1_output_loss: 10.3629 - val_y2_output_loss: 14.1971 - val_y1_output_root_mean_squared_error: 3.2039 - val_y2_output_root_mean_squared_error: 3.8125
# Epoch 5/500
# 614/614 [==============================] - 0s 130us/sample - loss: 22.1337 - y1_output_loss: 9.0594 - y2_output_loss: 13.0845 - y1_output_root_mean_squared_error: 3.0025 - y2_output_root_mean_squared_error: 3.6220 - val_loss: 25.7600 - val_y1_output_loss: 9.5173 - val_y2_output_loss: 15.8436 - val_y1_output_root_mean_squared_error: 3.0731 - val_y2_output_root_mean_squared_error: 4.0393
# Epoch 6/500
# 614/614 [==============================] - 0s 125us/sample - loss: 23.4625 - y1_output_loss: 9.0979 - y2_output_loss: 14.2470 - y1_output_root_mean_squared_error: 3.0288 - y2_output_root_mean_squared_error: 3.7800 - val_loss: 29.9947 - val_y1_output_loss: 9.5042 - val_y2_output_loss: 19.9285 - val_y1_output_root_mean_squared_error: 3.0618 - val_y2_output_root_mean_squared_error: 4.5409
# Epoch 7/500
# 614/614 [==============================] - 0s 134us/sample - loss: 20.4522 - y1_output_loss: 8.2829 - y2_output_loss: 12.0414 - y1_output_root_mean_squared_error: 2.8919 - y2_output_root_mean_squared_error: 3.4770 - val_loss: 20.1972 - val_y1_output_loss: 8.8172 - val_y2_output_loss: 11.7855 - val_y1_output_root_mean_squared_error: 2.9026 - val_y2_output_root_mean_squared_error: 3.4310
# Epoch 8/500
# 614/614 [==============================] - 0s 121us/sample - loss: 22.0975 - y1_output_loss: 8.5927 - y2_output_loss: 13.4141 - y1_output_root_mean_squared_error: 2.9396 - y2_output_root_mean_squared_error: 3.6683 - val_loss: 24.4067 - val_y1_output_loss: 10.0776 - val_y2_output_loss: 14.2325 - val_y1_output_root_mean_squared_error: 3.1386 - val_y2_output_root_mean_squared_error: 3.8152
# Epoch 9/500
# 614/614 [==============================] - 0s 122us/sample - loss: 23.4894 - y1_output_loss: 8.3044 - y2_output_loss: 14.9848 - y1_output_root_mean_squared_error: 2.8956 - y2_output_root_mean_squared_error: 3.8865 - val_loss: 20.8276 - val_y1_output_loss: 8.9989 - val_y2_output_loss: 11.9707 - val_y1_output_root_mean_squared_error: 2.9682 - val_y2_output_root_mean_squared_error: 3.4666
# Epoch 10/500
# 614/614 [==============================] - 0s 120us/sample - loss: 18.5443 - y1_output_loss: 7.8328 - y2_output_loss: 10.6402 - y1_output_root_mean_squared_error: 2.8079 - y2_output_root_mean_squared_error: 3.2650 - val_loss: 19.0908 - val_y1_output_loss: 8.5187 - val_y2_output_loss: 11.2585 - val_y1_output_root_mean_squared_error: 2.8342 - val_y2_output_root_mean_squared_error: 3.3254
# Epoch 11/500
# 614/614 [==============================] - 0s 122us/sample - loss: 19.8187 - y1_output_loss: 7.7948 - y2_output_loss: 11.9314 - y1_output_root_mean_squared_error: 2.8004 - y2_output_root_mean_squared_error: 3.4607 - val_loss: 21.8167 - val_y1_output_loss: 8.6822 - val_y2_output_loss: 13.0321 - val_y1_output_root_mean_squared_error: 2.9168 - val_y2_output_root_mean_squared_error: 3.6481
# Epoch 12/500
# 614/614 [==============================] - 0s 122us/sample - loss: 18.1239 - y1_output_loss: 7.3804 - y2_output_loss: 10.6523 - y1_output_root_mean_squared_error: 2.7227 - y2_output_root_mean_squared_error: 3.2727 - val_loss: 25.9976 - val_y1_output_loss: 8.9935 - val_y2_output_loss: 16.8521 - val_y1_output_root_mean_squared_error: 2.9319 - val_y2_output_root_mean_squared_error: 4.1715
# Epoch 13/500
# 614/614 [==============================] - 0s 121us/sample - loss: 29.2671 - y1_output_loss: 10.2481 - y2_output_loss: 19.4890 - y1_output_root_mean_squared_error: 3.1716 - y2_output_root_mean_squared_error: 4.3827 - val_loss: 95.0894 - val_y1_output_loss: 24.1230 - val_y2_output_loss: 68.0784 - val_y1_output_root_mean_squared_error: 4.9995 - val_y2_output_root_mean_squared_error: 8.3722
# Epoch 14/500
# 614/614 [==============================] - 0s 121us/sample - loss: 19.8482 - y1_output_loss: 7.6224 - y2_output_loss: 12.1093 - y1_output_root_mean_squared_error: 2.7710 - y2_output_root_mean_squared_error: 3.4885 - val_loss: 19.8178 - val_y1_output_loss: 9.4164 - val_y2_output_loss: 11.4183 - val_y1_output_root_mean_squared_error: 2.9465 - val_y2_output_root_mean_squared_error: 3.3371
# Epoch 15/500
# 614/614 [==============================] - 0s 128us/sample - loss: 23.0017 - y1_output_loss: 8.0114 - y2_output_loss: 14.7795 - y1_output_root_mean_squared_error: 2.8435 - y2_output_root_mean_squared_error: 3.8621 - val_loss: 18.7596 - val_y1_output_loss: 7.9483 - val_y2_output_loss: 11.2583 - val_y1_output_root_mean_squared_error: 2.7278 - val_y2_output_root_mean_squared_error: 3.3643
# Epoch 16/500
# 614/614 [==============================] - 0s 121us/sample - loss: 18.5353 - y1_output_loss: 7.3015 - y2_output_loss: 11.1494 - y1_output_root_mean_squared_error: 2.7044 - y2_output_root_mean_squared_error: 3.3499 - val_loss: 20.0390 - val_y1_output_loss: 8.0299 - val_y2_output_loss: 12.1345 - val_y1_output_root_mean_squared_error: 2.7775 - val_y2_output_root_mean_squared_error: 3.5106
# Epoch 17/500
# 614/614 [==============================] - 0s 118us/sample - loss: 18.8850 - y1_output_loss: 7.0515 - y2_output_loss: 11.9688 - y1_output_root_mean_squared_error: 2.6594 - y2_output_root_mean_squared_error: 3.4370 - val_loss: 33.9692 - val_y1_output_loss: 8.8854 - val_y2_output_loss: 24.4641 - val_y1_output_root_mean_squared_error: 2.9380 - val_y2_output_root_mean_squared_error: 5.0336
# Epoch 18/500
# 614/614 [==============================] - 0s 120us/sample - loss: 18.0474 - y1_output_loss: 7.2936 - y2_output_loss: 11.4118 - y1_output_root_mean_squared_error: 2.6675 - y2_output_root_mean_squared_error: 3.3063 - val_loss: 57.7469 - val_y1_output_loss: 11.6969 - val_y2_output_loss: 48.9704 - val_y1_output_root_mean_squared_error: 3.2664 - val_y2_output_root_mean_squared_error: 6.8613
# Epoch 19/500
# 614/614 [==============================] - 0s 119us/sample - loss: 17.7420 - y1_output_loss: 6.8429 - y2_output_loss: 10.9763 - y1_output_root_mean_squared_error: 2.6009 - y2_output_root_mean_squared_error: 3.3132 - val_loss: 19.0263 - val_y1_output_loss: 8.8036 - val_y2_output_loss: 11.8913 - val_y1_output_root_mean_squared_error: 2.8116 - val_y2_output_root_mean_squared_error: 3.3349
# Epoch 20/500
# 614/614 [==============================] - 0s 119us/sample - loss: 16.9194 - y1_output_loss: 6.3394 - y2_output_loss: 10.5403 - y1_output_root_mean_squared_error: 2.5254 - y2_output_root_mean_squared_error: 3.2468 - val_loss: 16.4136 - val_y1_output_loss: 6.8866 - val_y2_output_loss: 10.6928 - val_y1_output_root_mean_squared_error: 2.5057 - val_y2_output_root_mean_squared_error: 3.1835
# Epoch 21/500
# 614/614 [==============================] - 0s 119us/sample - loss: 16.1580 - y1_output_loss: 6.2757 - y2_output_loss: 9.7567 - y1_output_root_mean_squared_error: 2.5165 - y2_output_root_mean_squared_error: 3.1345 - val_loss: 15.0365 - val_y1_output_loss: 6.8977 - val_y2_output_loss: 9.0197 - val_y1_output_root_mean_squared_error: 2.5141 - val_y2_output_root_mean_squared_error: 2.9522
# Epoch 22/500
# 614/614 [==============================] - 0s 119us/sample - loss: 16.2394 - y1_output_loss: 5.8590 - y2_output_loss: 10.3215 - y1_output_root_mean_squared_error: 2.4291 - y2_output_root_mean_squared_error: 3.2154 - val_loss: 22.2979 - val_y1_output_loss: 6.9787 - val_y2_output_loss: 16.8364 - val_y1_output_root_mean_squared_error: 2.5297 - val_y2_output_root_mean_squared_error: 3.9873
# Epoch 23/500
# 614/614 [==============================] - 0s 119us/sample - loss: 14.8354 - y1_output_loss: 5.6507 - y2_output_loss: 9.1798 - y1_output_root_mean_squared_error: 2.3797 - y2_output_root_mean_squared_error: 3.0286 - val_loss: 66.4469 - val_y1_output_loss: 15.3850 - val_y2_output_loss: 54.5137 - val_y1_output_root_mean_squared_error: 3.7344 - val_y2_output_root_mean_squared_error: 7.2458
# Epoch 24/500
# 614/614 [==============================] - 0s 122us/sample - loss: 16.9347 - y1_output_loss: 6.3975 - y2_output_loss: 10.4470 - y1_output_root_mean_squared_error: 2.5359 - y2_output_root_mean_squared_error: 3.2409 - val_loss: 15.1822 - val_y1_output_loss: 6.1245 - val_y2_output_loss: 9.4354 - val_y1_output_root_mean_squared_error: 2.3802 - val_y2_output_root_mean_squared_error: 3.0849
# Epoch 25/500
# 614/614 [==============================] - 0s 124us/sample - loss: 15.5702 - y1_output_loss: 5.7927 - y2_output_loss: 9.7100 - y1_output_root_mean_squared_error: 2.4047 - y2_output_root_mean_squared_error: 3.1285 - val_loss: 25.1252 - val_y1_output_loss: 8.3733 - val_y2_output_loss: 16.2269 - val_y1_output_root_mean_squared_error: 2.9022 - val_y2_output_root_mean_squared_error: 4.0869
# Epoch 26/500
# 614/614 [==============================] - 0s 128us/sample - loss: 15.1956 - y1_output_loss: 5.7430 - y2_output_loss: 9.3551 - y1_output_root_mean_squared_error: 2.4055 - y2_output_root_mean_squared_error: 3.0675 - val_loss: 13.6220 - val_y1_output_loss: 6.7104 - val_y2_output_loss: 7.8843 - val_y1_output_root_mean_squared_error: 2.4480 - val_y2_output_root_mean_squared_error: 2.7621
# Epoch 27/500
# 614/614 [==============================] - 0s 124us/sample - loss: 13.6052 - y1_output_loss: 5.5436 - y2_output_loss: 8.1907 - y1_output_root_mean_squared_error: 2.3482 - y2_output_root_mean_squared_error: 2.8445 - val_loss: 35.7036 - val_y1_output_loss: 10.0118 - val_y2_output_loss: 24.6988 - val_y1_output_root_mean_squared_error: 3.1977 - val_y2_output_root_mean_squared_error: 5.0476
# Epoch 28/500
# 614/614 [==============================] - 0s 133us/sample - loss: 14.2597 - y1_output_loss: 5.4234 - y2_output_loss: 8.9171 - y1_output_root_mean_squared_error: 2.3156 - y2_output_root_mean_squared_error: 2.9829 - val_loss: 12.4683 - val_y1_output_loss: 5.5169 - val_y2_output_loss: 8.0062 - val_y1_output_root_mean_squared_error: 2.2277 - val_y2_output_root_mean_squared_error: 2.7396
# Epoch 29/500
# 614/614 [==============================] - 0s 122us/sample - loss: 12.1573 - y1_output_loss: 4.9177 - y2_output_loss: 7.2569 - y1_output_root_mean_squared_error: 2.2132 - y2_output_root_mean_squared_error: 2.6943 - val_loss: 26.1472 - val_y1_output_loss: 10.1843 - val_y2_output_loss: 18.1637 - val_y1_output_root_mean_squared_error: 3.0109 - val_y2_output_root_mean_squared_error: 4.1330
# Epoch 30/500
# 614/614 [==============================] - 0s 122us/sample - loss: 13.6933 - y1_output_loss: 5.1891 - y2_output_loss: 8.6456 - y1_output_root_mean_squared_error: 2.2805 - y2_output_root_mean_squared_error: 2.9142 - val_loss: 18.6067 - val_y1_output_loss: 7.4650 - val_y2_output_loss: 13.0336 - val_y1_output_root_mean_squared_error: 2.5545 - val_y2_output_root_mean_squared_error: 3.4758
# Epoch 31/500
# 614/614 [==============================] - 0s 127us/sample - loss: 11.7707 - y1_output_loss: 4.9763 - y2_output_loss: 6.7870 - y1_output_root_mean_squared_error: 2.2345 - y2_output_root_mean_squared_error: 2.6034 - val_loss: 12.7137 - val_y1_output_loss: 5.5598 - val_y2_output_loss: 7.6909 - val_y1_output_root_mean_squared_error: 2.2708 - val_y2_output_root_mean_squared_error: 2.7490
# Epoch 32/500
# 614/614 [==============================] - 0s 130us/sample - loss: 12.4444 - y1_output_loss: 4.8144 - y2_output_loss: 7.5540 - y1_output_root_mean_squared_error: 2.2008 - y2_output_root_mean_squared_error: 2.7570 - val_loss: 11.9769 - val_y1_output_loss: 5.8745 - val_y2_output_loss: 7.0340 - val_y1_output_root_mean_squared_error: 2.2604 - val_y2_output_root_mean_squared_error: 2.6206
# Epoch 33/500
# 614/614 [==============================] - 0s 130us/sample - loss: 13.2017 - y1_output_loss: 4.8755 - y2_output_loss: 8.2404 - y1_output_root_mean_squared_error: 2.2163 - y2_output_root_mean_squared_error: 2.8792 - val_loss: 12.1580 - val_y1_output_loss: 5.5180 - val_y2_output_loss: 7.2278 - val_y1_output_root_mean_squared_error: 2.2540 - val_y2_output_root_mean_squared_error: 2.6604
# Epoch 34/500
# 614/614 [==============================] - 0s 122us/sample - loss: 12.9635 - y1_output_loss: 4.8794 - y2_output_loss: 8.0522 - y1_output_root_mean_squared_error: 2.2128 - y2_output_root_mean_squared_error: 2.8402 - val_loss: 17.6396 - val_y1_output_loss: 5.4311 - val_y2_output_loss: 12.1875 - val_y1_output_root_mean_squared_error: 2.2781 - val_y2_output_root_mean_squared_error: 3.5284
# Epoch 35/500
# 614/614 [==============================] - 0s 126us/sample - loss: 11.9278 - y1_output_loss: 4.2258 - y2_output_loss: 7.5923 - y1_output_root_mean_squared_error: 2.0656 - y2_output_root_mean_squared_error: 2.7679 - val_loss: 10.4295 - val_y1_output_loss: 4.6187 - val_y2_output_loss: 6.3445 - val_y1_output_root_mean_squared_error: 2.0500 - val_y2_output_root_mean_squared_error: 2.4954
# Epoch 36/500
# 614/614 [==============================] - 0s 132us/sample - loss: 12.1188 - y1_output_loss: 4.4717 - y2_output_loss: 7.6051 - y1_output_root_mean_squared_error: 2.1224 - y2_output_root_mean_squared_error: 2.7594 - val_loss: 21.2445 - val_y1_output_loss: 8.3872 - val_y2_output_loss: 14.6258 - val_y1_output_root_mean_squared_error: 2.7177 - val_y2_output_root_mean_squared_error: 3.7227
# Epoch 37/500
# 614/614 [==============================] - 0s 121us/sample - loss: 13.3010 - y1_output_loss: 4.8676 - y2_output_loss: 8.4375 - y1_output_root_mean_squared_error: 2.1990 - y2_output_root_mean_squared_error: 2.9095 - val_loss: 17.1785 - val_y1_output_loss: 6.2914 - val_y2_output_loss: 10.6326 - val_y1_output_root_mean_squared_error: 2.4997 - val_y2_output_root_mean_squared_error: 3.3061
# Epoch 38/500
# 614/614 [==============================] - 0s 119us/sample - loss: 12.1126 - y1_output_loss: 4.5189 - y2_output_loss: 7.6182 - y1_output_root_mean_squared_error: 2.1122 - y2_output_root_mean_squared_error: 2.7660 - val_loss: 13.5316 - val_y1_output_loss: 5.3135 - val_y2_output_loss: 8.1886 - val_y1_output_root_mean_squared_error: 2.2732 - val_y2_output_root_mean_squared_error: 2.8921
# Epoch 39/500
# 614/614 [==============================] - 0s 119us/sample - loss: 10.5084 - y1_output_loss: 4.1207 - y2_output_loss: 6.4840 - y1_output_root_mean_squared_error: 2.0076 - y2_output_root_mean_squared_error: 2.5452 - val_loss: 14.3826 - val_y1_output_loss: 5.9155 - val_y2_output_loss: 8.4760 - val_y1_output_root_mean_squared_error: 2.3989 - val_y2_output_root_mean_squared_error: 2.9374
# Epoch 40/500
# 614/614 [==============================] - 0s 119us/sample - loss: 11.3067 - y1_output_loss: 4.1826 - y2_output_loss: 7.0381 - y1_output_root_mean_squared_error: 2.0518 - y2_output_root_mean_squared_error: 2.6640 - val_loss: 10.1611 - val_y1_output_loss: 5.2206 - val_y2_output_loss: 5.8415 - val_y1_output_root_mean_squared_error: 2.1335 - val_y2_output_root_mean_squared_error: 2.3684
# Epoch 41/500
# 614/614 [==============================] - 0s 119us/sample - loss: 10.2546 - y1_output_loss: 3.7117 - y2_output_loss: 6.6080 - y1_output_root_mean_squared_error: 1.9279 - y2_output_root_mean_squared_error: 2.5570 - val_loss: 12.3463 - val_y1_output_loss: 5.9727 - val_y2_output_loss: 7.4234 - val_y1_output_root_mean_squared_error: 2.3015 - val_y2_output_root_mean_squared_error: 2.6551
# Epoch 42/500
# 614/614 [==============================] - 0s 121us/sample - loss: 9.1399 - y1_output_loss: 3.3008 - y2_output_loss: 5.8457 - y1_output_root_mean_squared_error: 1.8229 - y2_output_root_mean_squared_error: 2.4118 - val_loss: 10.4580 - val_y1_output_loss: 3.5579 - val_y2_output_loss: 7.7483 - val_y1_output_root_mean_squared_error: 1.7731 - val_y2_output_root_mean_squared_error: 2.7044
# Epoch 43/500
# 614/614 [==============================] - 0s 121us/sample - loss: 9.9899 - y1_output_loss: 3.4425 - y2_output_loss: 6.4590 - y1_output_root_mean_squared_error: 1.8636 - y2_output_root_mean_squared_error: 2.5528 - val_loss: 8.5860 - val_y1_output_loss: 3.6855 - val_y2_output_loss: 5.5203 - val_y1_output_root_mean_squared_error: 1.8076 - val_y2_output_root_mean_squared_error: 2.3062
# Epoch 44/500
# 614/614 [==============================] - 0s 120us/sample - loss: 9.3166 - y1_output_loss: 3.5733 - y2_output_loss: 5.6669 - y1_output_root_mean_squared_error: 1.8987 - y2_output_root_mean_squared_error: 2.3899 - val_loss: 8.1652 - val_y1_output_loss: 3.3988 - val_y2_output_loss: 5.2121 - val_y1_output_root_mean_squared_error: 1.7596 - val_y2_output_root_mean_squared_error: 2.2514
# Epoch 45/500
# 614/614 [==============================] - 0s 119us/sample - loss: 8.9657 - y1_output_loss: 3.1872 - y2_output_loss: 5.7937 - y1_output_root_mean_squared_error: 1.7687 - y2_output_root_mean_squared_error: 2.4161 - val_loss: 8.5716 - val_y1_output_loss: 3.8057 - val_y2_output_loss: 5.2178 - val_y1_output_root_mean_squared_error: 1.8444 - val_y2_output_root_mean_squared_error: 2.2737
# Epoch 46/500
# 614/614 [==============================] - 0s 120us/sample - loss: 9.9631 - y1_output_loss: 3.3045 - y2_output_loss: 6.6241 - y1_output_root_mean_squared_error: 1.8220 - y2_output_root_mean_squared_error: 2.5775 - val_loss: 7.4475 - val_y1_output_loss: 2.8928 - val_y2_output_loss: 4.8971 - val_y1_output_root_mean_squared_error: 1.6159 - val_y2_output_root_mean_squared_error: 2.1992
# Epoch 47/500
# 614/614 [==============================] - 0s 116us/sample - loss: 9.3490 - y1_output_loss: 3.2986 - y2_output_loss: 6.0702 - y1_output_root_mean_squared_error: 1.8099 - y2_output_root_mean_squared_error: 2.4644 - val_loss: 13.9850 - val_y1_output_loss: 4.6858 - val_y2_output_loss: 10.2301 - val_y1_output_root_mean_squared_error: 2.0379 - val_y2_output_root_mean_squared_error: 3.1356
# Epoch 48/500
# 614/614 [==============================] - 0s 117us/sample - loss: 8.5227 - y1_output_loss: 3.0211 - y2_output_loss: 5.4571 - y1_output_root_mean_squared_error: 1.7375 - y2_output_root_mean_squared_error: 2.3460 - val_loss: 10.6066 - val_y1_output_loss: 4.3534 - val_y2_output_loss: 6.0812 - val_y1_output_root_mean_squared_error: 2.0926 - val_y2_output_root_mean_squared_error: 2.4955
# Epoch 49/500
# 614/614 [==============================] - 0s 118us/sample - loss: 7.5361 - y1_output_loss: 2.6058 - y2_output_loss: 5.0438 - y1_output_root_mean_squared_error: 1.5892 - y2_output_root_mean_squared_error: 2.2384 - val_loss: 9.0634 - val_y1_output_loss: 3.3885 - val_y2_output_loss: 6.4784 - val_y1_output_root_mean_squared_error: 1.7112 - val_y2_output_root_mean_squared_error: 2.4769
# Epoch 50/500
# 614/614 [==============================] - 0s 116us/sample - loss: 8.1101 - y1_output_loss: 2.8919 - y2_output_loss: 5.2412 - y1_output_root_mean_squared_error: 1.6959 - y2_output_root_mean_squared_error: 2.2878 - val_loss: 7.3210 - val_y1_output_loss: 3.2584 - val_y2_output_loss: 4.5471 - val_y1_output_root_mean_squared_error: 1.6885 - val_y2_output_root_mean_squared_error: 2.1142
# Epoch 51/500
# 614/614 [==============================] - 0s 117us/sample - loss: 7.9734 - y1_output_loss: 2.7909 - y2_output_loss: 5.1631 - y1_output_root_mean_squared_error: 1.6669 - y2_output_root_mean_squared_error: 2.2792 - val_loss: 11.2911 - val_y1_output_loss: 4.6941 - val_y2_output_loss: 6.3551 - val_y1_output_root_mean_squared_error: 2.1738 - val_y2_output_root_mean_squared_error: 2.5623
# Epoch 52/500
# 614/614 [==============================] - 0s 118us/sample - loss: 9.1088 - y1_output_loss: 2.9319 - y2_output_loss: 6.1418 - y1_output_root_mean_squared_error: 1.7165 - y2_output_root_mean_squared_error: 2.4824 - val_loss: 7.4489 - val_y1_output_loss: 2.8186 - val_y2_output_loss: 5.2404 - val_y1_output_root_mean_squared_error: 1.5595 - val_y2_output_root_mean_squared_error: 2.2399
# Epoch 53/500
# 614/614 [==============================] - 0s 121us/sample - loss: 8.7081 - y1_output_loss: 2.9829 - y2_output_loss: 5.7291 - y1_output_root_mean_squared_error: 1.7328 - y2_output_root_mean_squared_error: 2.3886 - val_loss: 7.9007 - val_y1_output_loss: 2.6737 - val_y2_output_loss: 5.2556 - val_y1_output_root_mean_squared_error: 1.5833 - val_y2_output_root_mean_squared_error: 2.3225
# Epoch 54/500
# 614/614 [==============================] - 0s 123us/sample - loss: 6.5743 - y1_output_loss: 2.3353 - y2_output_loss: 4.2286 - y1_output_root_mean_squared_error: 1.5333 - y2_output_root_mean_squared_error: 2.0551 - val_loss: 8.9957 - val_y1_output_loss: 3.3582 - val_y2_output_loss: 6.2946 - val_y1_output_root_mean_squared_error: 1.7195 - val_y2_output_root_mean_squared_error: 2.4575
# Epoch 55/500
# 614/614 [==============================] - 0s 118us/sample - loss: 7.3684 - y1_output_loss: 2.4299 - y2_output_loss: 4.9616 - y1_output_root_mean_squared_error: 1.5557 - y2_output_root_mean_squared_error: 2.2245 - val_loss: 9.0124 - val_y1_output_loss: 3.6402 - val_y2_output_loss: 5.6389 - val_y1_output_root_mean_squared_error: 1.8407 - val_y2_output_root_mean_squared_error: 2.3715
# Epoch 56/500
# 614/614 [==============================] - 0s 116us/sample - loss: 6.0509 - y1_output_loss: 2.2150 - y2_output_loss: 3.9162 - y1_output_root_mean_squared_error: 1.4863 - y2_output_root_mean_squared_error: 1.9600 - val_loss: 27.1554 - val_y1_output_loss: 7.7437 - val_y2_output_loss: 18.6769 - val_y1_output_root_mean_squared_error: 2.8341 - val_y2_output_root_mean_squared_error: 4.3730
# Epoch 57/500
# 614/614 [==============================] - 0s 118us/sample - loss: 7.2269 - y1_output_loss: 2.5183 - y2_output_loss: 4.6946 - y1_output_root_mean_squared_error: 1.5930 - y2_output_root_mean_squared_error: 2.1655 - val_loss: 7.2514 - val_y1_output_loss: 2.7157 - val_y2_output_loss: 5.0714 - val_y1_output_root_mean_squared_error: 1.5430 - val_y2_output_root_mean_squared_error: 2.2069
# Epoch 58/500
# 614/614 [==============================] - 0s 118us/sample - loss: 7.3783 - y1_output_loss: 2.3727 - y2_output_loss: 4.9542 - y1_output_root_mean_squared_error: 1.5434 - y2_output_root_mean_squared_error: 2.2352 - val_loss: 6.4034 - val_y1_output_loss: 2.5946 - val_y2_output_loss: 4.1234 - val_y1_output_root_mean_squared_error: 1.5266 - val_y2_output_root_mean_squared_error: 2.0181
# Epoch 59/500
# 614/614 [==============================] - 0s 124us/sample - loss: 7.3147 - y1_output_loss: 2.4801 - y2_output_loss: 4.7672 - y1_output_root_mean_squared_error: 1.5820 - y2_output_root_mean_squared_error: 2.1936 - val_loss: 7.0480 - val_y1_output_loss: 2.7890 - val_y2_output_loss: 4.6099 - val_y1_output_root_mean_squared_error: 1.5791 - val_y2_output_root_mean_squared_error: 2.1342
# Epoch 60/500
# 614/614 [==============================] - 0s 118us/sample - loss: 7.0115 - y1_output_loss: 2.2693 - y2_output_loss: 4.7721 - y1_output_root_mean_squared_error: 1.4966 - y2_output_root_mean_squared_error: 2.1844 - val_loss: 11.2853 - val_y1_output_loss: 4.5140 - val_y2_output_loss: 7.3694 - val_y1_output_root_mean_squared_error: 2.0209 - val_y2_output_root_mean_squared_error: 2.6835
# Epoch 61/500
# 614/614 [==============================] - 0s 119us/sample - loss: 6.8958 - y1_output_loss: 2.1473 - y2_output_loss: 4.6843 - y1_output_root_mean_squared_error: 1.4720 - y2_output_root_mean_squared_error: 2.1747 - val_loss: 6.5110 - val_y1_output_loss: 1.9430 - val_y2_output_loss: 4.6151 - val_y1_output_root_mean_squared_error: 1.3359 - val_y2_output_root_mean_squared_error: 2.1740
# Epoch 62/500
# 614/614 [==============================] - 0s 119us/sample - loss: 5.8125 - y1_output_loss: 1.8720 - y2_output_loss: 3.9473 - y1_output_root_mean_squared_error: 1.3745 - y2_output_root_mean_squared_error: 1.9807 - val_loss: 6.0254 - val_y1_output_loss: 2.1984 - val_y2_output_loss: 3.9391 - val_y1_output_root_mean_squared_error: 1.4373 - val_y2_output_root_mean_squared_error: 1.9899
# Epoch 63/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.6683 - y1_output_loss: 1.8128 - y2_output_loss: 3.8365 - y1_output_root_mean_squared_error: 1.3507 - y2_output_root_mean_squared_error: 1.9606 - val_loss: 7.1300 - val_y1_output_loss: 2.6802 - val_y2_output_loss: 4.8009 - val_y1_output_root_mean_squared_error: 1.5499 - val_y2_output_root_mean_squared_error: 2.1744
# Epoch 64/500
# 614/614 [==============================] - 0s 123us/sample - loss: 6.5774 - y1_output_loss: 2.1353 - y2_output_loss: 4.4555 - y1_output_root_mean_squared_error: 1.4534 - y2_output_root_mean_squared_error: 2.1131 - val_loss: 6.0573 - val_y1_output_loss: 1.7760 - val_y2_output_loss: 4.3292 - val_y1_output_root_mean_squared_error: 1.2787 - val_y2_output_root_mean_squared_error: 2.1029
# Epoch 65/500
# 614/614 [==============================] - 0s 125us/sample - loss: 6.0322 - y1_output_loss: 1.8999 - y2_output_loss: 4.0981 - y1_output_root_mean_squared_error: 1.3827 - y2_output_root_mean_squared_error: 2.0299 - val_loss: 5.6931 - val_y1_output_loss: 2.1227 - val_y2_output_loss: 3.8682 - val_y1_output_root_mean_squared_error: 1.3658 - val_y2_output_root_mean_squared_error: 1.9565
# Epoch 66/500
# 614/614 [==============================] - 0s 118us/sample - loss: 7.8272 - y1_output_loss: 2.3087 - y2_output_loss: 5.4941 - y1_output_root_mean_squared_error: 1.5268 - y2_output_root_mean_squared_error: 2.3444 - val_loss: 6.7819 - val_y1_output_loss: 1.9659 - val_y2_output_loss: 5.0900 - val_y1_output_root_mean_squared_error: 1.3237 - val_y2_output_root_mean_squared_error: 2.2427
# Epoch 67/500
# 614/614 [==============================] - 0s 119us/sample - loss: 5.3908 - y1_output_loss: 1.7193 - y2_output_loss: 3.6909 - y1_output_root_mean_squared_error: 1.2989 - y2_output_root_mean_squared_error: 1.9245 - val_loss: 5.7655 - val_y1_output_loss: 1.6410 - val_y2_output_loss: 4.3614 - val_y1_output_root_mean_squared_error: 1.2146 - val_y2_output_root_mean_squared_error: 2.0713
# Epoch 68/500
# 614/614 [==============================] - 0s 121us/sample - loss: 8.0203 - y1_output_loss: 2.4543 - y2_output_loss: 5.6098 - y1_output_root_mean_squared_error: 1.5708 - y2_output_root_mean_squared_error: 2.3564 - val_loss: 20.1104 - val_y1_output_loss: 3.5563 - val_y2_output_loss: 16.9522 - val_y1_output_root_mean_squared_error: 1.8079 - val_y2_output_root_mean_squared_error: 4.1039
# Epoch 69/500
# 614/614 [==============================] - 0s 120us/sample - loss: 5.1038 - y1_output_loss: 1.6379 - y2_output_loss: 3.5339 - y1_output_root_mean_squared_error: 1.2730 - y2_output_root_mean_squared_error: 1.8663 - val_loss: 16.0570 - val_y1_output_loss: 2.7932 - val_y2_output_loss: 12.9208 - val_y1_output_root_mean_squared_error: 1.6786 - val_y2_output_root_mean_squared_error: 3.6386
# Epoch 70/500
# 614/614 [==============================] - 0s 120us/sample - loss: 6.5242 - y1_output_loss: 1.9885 - y2_output_loss: 4.5295 - y1_output_root_mean_squared_error: 1.3989 - y2_output_root_mean_squared_error: 2.1371 - val_loss: 9.2953 - val_y1_output_loss: 2.7560 - val_y2_output_loss: 6.3577 - val_y1_output_root_mean_squared_error: 1.6600 - val_y2_output_root_mean_squared_error: 2.5573
# Epoch 71/500
# 614/614 [==============================] - 0s 121us/sample - loss: 6.2878 - y1_output_loss: 1.9733 - y2_output_loss: 4.3366 - y1_output_root_mean_squared_error: 1.3991 - y2_output_root_mean_squared_error: 2.0809 - val_loss: 10.2530 - val_y1_output_loss: 2.8470 - val_y2_output_loss: 7.3423 - val_y1_output_root_mean_squared_error: 1.6675 - val_y2_output_root_mean_squared_error: 2.7336
# Epoch 72/500
# 614/614 [==============================] - 0s 120us/sample - loss: 5.3507 - y1_output_loss: 1.6595 - y2_output_loss: 3.6437 - y1_output_root_mean_squared_error: 1.2943 - y2_output_root_mean_squared_error: 1.9172 - val_loss: 4.9331 - val_y1_output_loss: 1.5125 - val_y2_output_loss: 3.4802 - val_y1_output_root_mean_squared_error: 1.1951 - val_y2_output_root_mean_squared_error: 1.8721
# Epoch 73/500
# 614/614 [==============================] - 0s 118us/sample - loss: 5.4839 - y1_output_loss: 1.5760 - y2_output_loss: 3.9511 - y1_output_root_mean_squared_error: 1.2605 - y2_output_root_mean_squared_error: 1.9735 - val_loss: 21.0753 - val_y1_output_loss: 3.7238 - val_y2_output_loss: 17.7753 - val_y1_output_root_mean_squared_error: 1.8581 - val_y2_output_root_mean_squared_error: 4.1979
# Epoch 74/500
# 614/614 [==============================] - 0s 126us/sample - loss: 6.3045 - y1_output_loss: 1.8530 - y2_output_loss: 4.3918 - y1_output_root_mean_squared_error: 1.3677 - y2_output_root_mean_squared_error: 2.1057 - val_loss: 5.7690 - val_y1_output_loss: 2.0279 - val_y2_output_loss: 3.6553 - val_y1_output_root_mean_squared_error: 1.4241 - val_y2_output_root_mean_squared_error: 1.9341
# Epoch 75/500
# 614/614 [==============================] - 0s 119us/sample - loss: 5.3377 - y1_output_loss: 1.5812 - y2_output_loss: 3.7384 - y1_output_root_mean_squared_error: 1.2527 - y2_output_root_mean_squared_error: 1.9412 - val_loss: 4.9690 - val_y1_output_loss: 1.5558 - val_y2_output_loss: 3.3760 - val_y1_output_root_mean_squared_error: 1.2403 - val_y2_output_root_mean_squared_error: 1.8522
# Epoch 76/500
# 614/614 [==============================] - 0s 121us/sample - loss: 4.4152 - y1_output_loss: 1.3903 - y2_output_loss: 3.0028 - y1_output_root_mean_squared_error: 1.1792 - y2_output_root_mean_squared_error: 1.7391 - val_loss: 5.9476 - val_y1_output_loss: 1.6597 - val_y2_output_loss: 4.2613 - val_y1_output_root_mean_squared_error: 1.2817 - val_y2_output_root_mean_squared_error: 2.0748
# Epoch 77/500
# 614/614 [==============================] - 0s 120us/sample - loss: 5.3197 - y1_output_loss: 1.5729 - y2_output_loss: 3.7273 - y1_output_root_mean_squared_error: 1.2582 - y2_output_root_mean_squared_error: 1.9331 - val_loss: 4.4751 - val_y1_output_loss: 1.3119 - val_y2_output_loss: 3.2708 - val_y1_output_root_mean_squared_error: 1.0894 - val_y2_output_root_mean_squared_error: 1.8134
# Epoch 78/500
# 614/614 [==============================] - 0s 120us/sample - loss: 4.2190 - y1_output_loss: 1.2591 - y2_output_loss: 2.9566 - y1_output_root_mean_squared_error: 1.1172 - y2_output_root_mean_squared_error: 1.7236 - val_loss: 5.0237 - val_y1_output_loss: 1.4797 - val_y2_output_loss: 3.4560 - val_y1_output_root_mean_squared_error: 1.2179 - val_y2_output_root_mean_squared_error: 1.8816
# Epoch 79/500
# 614/614 [==============================] - 0s 119us/sample - loss: 4.0373 - y1_output_loss: 1.1630 - y2_output_loss: 2.8389 - y1_output_root_mean_squared_error: 1.0826 - y2_output_root_mean_squared_error: 1.6927 - val_loss: 4.2923 - val_y1_output_loss: 1.1481 - val_y2_output_loss: 3.0949 - val_y1_output_root_mean_squared_error: 1.0702 - val_y2_output_root_mean_squared_error: 1.7740
# Epoch 80/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.0874 - y1_output_loss: 1.0928 - y2_output_loss: 3.0851 - y1_output_root_mean_squared_error: 1.0485 - y2_output_root_mean_squared_error: 1.7286 - val_loss: 16.1691 - val_y1_output_loss: 1.9475 - val_y2_output_loss: 14.0224 - val_y1_output_root_mean_squared_error: 1.4118 - val_y2_output_root_mean_squared_error: 3.7651
# Epoch 81/500
# 614/614 [==============================] - 0s 119us/sample - loss: 5.9376 - y1_output_loss: 1.6653 - y2_output_loss: 4.3907 - y1_output_root_mean_squared_error: 1.2888 - y2_output_root_mean_squared_error: 2.0680 - val_loss: 11.3993 - val_y1_output_loss: 2.0609 - val_y2_output_loss: 9.2527 - val_y1_output_root_mean_squared_error: 1.4083 - val_y2_output_root_mean_squared_error: 3.0686
# Epoch 82/500
# 614/614 [==============================] - 0s 118us/sample - loss: 3.4281 - y1_output_loss: 1.0850 - y2_output_loss: 2.4085 - y1_output_root_mean_squared_error: 1.0353 - y2_output_root_mean_squared_error: 1.5350 - val_loss: 8.1597 - val_y1_output_loss: 2.2316 - val_y2_output_loss: 6.0133 - val_y1_output_root_mean_squared_error: 1.4447 - val_y2_output_root_mean_squared_error: 2.4642
# Epoch 83/500
# 614/614 [==============================] - 0s 119us/sample - loss: 4.7022 - y1_output_loss: 1.2963 - y2_output_loss: 3.4273 - y1_output_root_mean_squared_error: 1.1426 - y2_output_root_mean_squared_error: 1.8430 - val_loss: 6.2744 - val_y1_output_loss: 1.1212 - val_y2_output_loss: 5.1013 - val_y1_output_root_mean_squared_error: 1.0380 - val_y2_output_root_mean_squared_error: 2.2797
# Epoch 84/500
# 614/614 [==============================] - 0s 118us/sample - loss: 5.1056 - y1_output_loss: 1.3265 - y2_output_loss: 3.7778 - y1_output_root_mean_squared_error: 1.1478 - y2_output_root_mean_squared_error: 1.9463 - val_loss: 6.9150 - val_y1_output_loss: 1.8568 - val_y2_output_loss: 5.0112 - val_y1_output_root_mean_squared_error: 1.3422 - val_y2_output_root_mean_squared_error: 2.2613
# Epoch 85/500
# 614/614 [==============================] - 0s 118us/sample - loss: 4.7285 - y1_output_loss: 1.3294 - y2_output_loss: 3.4278 - y1_output_root_mean_squared_error: 1.1419 - y2_output_root_mean_squared_error: 1.8506 - val_loss: 11.4170 - val_y1_output_loss: 3.9314 - val_y2_output_loss: 7.1967 - val_y1_output_root_mean_squared_error: 2.0135 - val_y2_output_root_mean_squared_error: 2.7135
# Epoch 86/500
# 614/614 [==============================] - 0s 122us/sample - loss: 4.1895 - y1_output_loss: 1.0686 - y2_output_loss: 3.1285 - y1_output_root_mean_squared_error: 1.0379 - y2_output_root_mean_squared_error: 1.7642 - val_loss: 3.7081 - val_y1_output_loss: 0.9858 - val_y2_output_loss: 2.7304 - val_y1_output_root_mean_squared_error: 0.9618 - val_y2_output_root_mean_squared_error: 1.6683
# Epoch 87/500
# 614/614 [==============================] - 0s 122us/sample - loss: 2.9249 - y1_output_loss: 0.7417 - y2_output_loss: 2.1692 - y1_output_root_mean_squared_error: 0.8599 - y2_output_root_mean_squared_error: 1.4783 - val_loss: 4.0808 - val_y1_output_loss: 0.9348 - val_y2_output_loss: 3.1406 - val_y1_output_root_mean_squared_error: 0.9477 - val_y2_output_root_mean_squared_error: 1.7840
# Epoch 88/500
# 614/614 [==============================] - 0s 122us/sample - loss: 4.1023 - y1_output_loss: 1.0201 - y2_output_loss: 3.0504 - y1_output_root_mean_squared_error: 1.0131 - y2_output_root_mean_squared_error: 1.7538 - val_loss: 5.3049 - val_y1_output_loss: 1.3323 - val_y2_output_loss: 3.9035 - val_y1_output_root_mean_squared_error: 1.1398 - val_y2_output_root_mean_squared_error: 2.0014
# Epoch 89/500
# 614/614 [==============================] - 0s 118us/sample - loss: 3.5763 - y1_output_loss: 0.8232 - y2_output_loss: 2.7409 - y1_output_root_mean_squared_error: 0.9045 - y2_output_root_mean_squared_error: 1.6608 - val_loss: 3.3253 - val_y1_output_loss: 0.7627 - val_y2_output_loss: 2.5365 - val_y1_output_root_mean_squared_error: 0.8537 - val_y2_output_root_mean_squared_error: 1.6113
# Epoch 90/500
# 614/614 [==============================] - 0s 120us/sample - loss: 4.6233 - y1_output_loss: 1.2442 - y2_output_loss: 3.4810 - y1_output_root_mean_squared_error: 1.0964 - y2_output_root_mean_squared_error: 1.8497 - val_loss: 10.5622 - val_y1_output_loss: 2.8744 - val_y2_output_loss: 7.6708 - val_y1_output_root_mean_squared_error: 1.7093 - val_y2_output_root_mean_squared_error: 2.7641
# Epoch 91/500
# 614/614 [==============================] - 0s 122us/sample - loss: 3.6492 - y1_output_loss: 0.9227 - y2_output_loss: 2.7065 - y1_output_root_mean_squared_error: 0.9625 - y2_output_root_mean_squared_error: 1.6501 - val_loss: 5.5533 - val_y1_output_loss: 1.3004 - val_y2_output_loss: 4.1547 - val_y1_output_root_mean_squared_error: 1.1475 - val_y2_output_root_mean_squared_error: 2.0583
# Epoch 92/500
# 614/614 [==============================] - 0s 125us/sample - loss: 4.0465 - y1_output_loss: 1.0525 - y2_output_loss: 3.0350 - y1_output_root_mean_squared_error: 1.0282 - y2_output_root_mean_squared_error: 1.7290 - val_loss: 5.4686 - val_y1_output_loss: 1.5195 - val_y2_output_loss: 3.9258 - val_y1_output_root_mean_squared_error: 1.2130 - val_y2_output_root_mean_squared_error: 1.9993
# Epoch 93/500
# 614/614 [==============================] - 0s 118us/sample - loss: 2.8321 - y1_output_loss: 0.7643 - y2_output_loss: 2.0437 - y1_output_root_mean_squared_error: 0.8783 - y2_output_root_mean_squared_error: 1.4355 - val_loss: 2.8280 - val_y1_output_loss: 0.5548 - val_y2_output_loss: 2.2612 - val_y1_output_root_mean_squared_error: 0.7312 - val_y2_output_root_mean_squared_error: 1.5144
# Epoch 94/500
# 614/614 [==============================] - 0s 123us/sample - loss: 4.2587 - y1_output_loss: 1.0847 - y2_output_loss: 3.1548 - y1_output_root_mean_squared_error: 1.0421 - y2_output_root_mean_squared_error: 1.7812 - val_loss: 4.8429 - val_y1_output_loss: 1.2639 - val_y2_output_loss: 3.4852 - val_y1_output_root_mean_squared_error: 1.1349 - val_y2_output_root_mean_squared_error: 1.8855
# Epoch 95/500
# 614/614 [==============================] - 0s 122us/sample - loss: 3.8464 - y1_output_loss: 0.9739 - y2_output_loss: 2.8492 - y1_output_root_mean_squared_error: 0.9887 - y2_output_root_mean_squared_error: 1.6938 - val_loss: 4.5697 - val_y1_output_loss: 1.0839 - val_y2_output_loss: 3.4460 - val_y1_output_root_mean_squared_error: 1.0410 - val_y2_output_root_mean_squared_error: 1.8671
# Epoch 96/500
# 614/614 [==============================] - 0s 121us/sample - loss: 3.3016 - y1_output_loss: 0.8146 - y2_output_loss: 2.4589 - y1_output_root_mean_squared_error: 0.9056 - y2_output_root_mean_squared_error: 1.5753 - val_loss: 4.8212 - val_y1_output_loss: 1.3760 - val_y2_output_loss: 3.4532 - val_y1_output_root_mean_squared_error: 1.1407 - val_y2_output_root_mean_squared_error: 1.8761
# Epoch 97/500
# 614/614 [==============================] - 0s 118us/sample - loss: 3.8177 - y1_output_loss: 0.9522 - y2_output_loss: 2.8563 - y1_output_root_mean_squared_error: 0.9757 - y2_output_root_mean_squared_error: 1.6928 - val_loss: 4.4735 - val_y1_output_loss: 1.1031 - val_y2_output_loss: 3.3176 - val_y1_output_root_mean_squared_error: 1.0680 - val_y2_output_root_mean_squared_error: 1.8256
# Epoch 98/500
# 614/614 [==============================] - 0s 121us/sample - loss: 2.5265 - y1_output_loss: 0.6181 - y2_output_loss: 1.9689 - y1_output_root_mean_squared_error: 0.7769 - y2_output_root_mean_squared_error: 1.3867 - val_loss: 25.6570 - val_y1_output_loss: 7.3379 - val_y2_output_loss: 18.1900 - val_y1_output_root_mean_squared_error: 2.6875 - val_y2_output_root_mean_squared_error: 4.2935
# Epoch 99/500
# 614/614 [==============================] - 0s 122us/sample - loss: 4.6025 - y1_output_loss: 1.1501 - y2_output_loss: 3.4371 - y1_output_root_mean_squared_error: 1.0765 - y2_output_root_mean_squared_error: 1.8557 - val_loss: 2.6087 - val_y1_output_loss: 0.5716 - val_y2_output_loss: 2.0096 - val_y1_output_root_mean_squared_error: 0.7327 - val_y2_output_root_mean_squared_error: 1.4394
# Epoch 100/500
# 614/614 [==============================] - 0s 121us/sample - loss: 2.9674 - y1_output_loss: 0.6731 - y2_output_loss: 2.3126 - y1_output_root_mean_squared_error: 0.8226 - y2_output_root_mean_squared_error: 1.5135 - val_loss: 6.4146 - val_y1_output_loss: 1.6403 - val_y2_output_loss: 4.7157 - val_y1_output_root_mean_squared_error: 1.2604 - val_y2_output_root_mean_squared_error: 2.1968
# Epoch 101/500
# 614/614 [==============================] - 0s 115us/sample - loss: 2.6530 - y1_output_loss: 0.6540 - y2_output_loss: 1.9937 - y1_output_root_mean_squared_error: 0.8115 - y2_output_root_mean_squared_error: 1.4122 - val_loss: 3.8605 - val_y1_output_loss: 0.6260 - val_y2_output_loss: 3.2224 - val_y1_output_root_mean_squared_error: 0.7874 - val_y2_output_root_mean_squared_error: 1.8001
# Epoch 102/500
# 614/614 [==============================] - 0s 124us/sample - loss: 3.9165 - y1_output_loss: 1.0489 - y2_output_loss: 2.8427 - y1_output_root_mean_squared_error: 1.0268 - y2_output_root_mean_squared_error: 1.6918 - val_loss: 2.7367 - val_y1_output_loss: 0.5388 - val_y2_output_loss: 2.1964 - val_y1_output_root_mean_squared_error: 0.7342 - val_y2_output_root_mean_squared_error: 1.4825
# Epoch 103/500
# 614/614 [==============================] - 0s 121us/sample - loss: 3.6179 - y1_output_loss: 0.8222 - y2_output_loss: 2.7725 - y1_output_root_mean_squared_error: 0.9103 - y2_output_root_mean_squared_error: 1.6701 - val_loss: 3.4577 - val_y1_output_loss: 0.5517 - val_y2_output_loss: 2.8972 - val_y1_output_root_mean_squared_error: 0.7374 - val_y2_output_root_mean_squared_error: 1.7070
# Epoch 104/500
# 614/614 [==============================] - 0s 121us/sample - loss: 2.7798 - y1_output_loss: 0.5980 - y2_output_loss: 2.1775 - y1_output_root_mean_squared_error: 0.7707 - y2_output_root_mean_squared_error: 1.4784 - val_loss: 3.3820 - val_y1_output_loss: 0.5861 - val_y2_output_loss: 2.7717 - val_y1_output_root_mean_squared_error: 0.7542 - val_y2_output_root_mean_squared_error: 1.6773
# Epoch 105/500
# 614/614 [==============================] - 0s 118us/sample - loss: 2.8506 - y1_output_loss: 0.6087 - y2_output_loss: 2.2279 - y1_output_root_mean_squared_error: 0.7826 - y2_output_root_mean_squared_error: 1.4960 - val_loss: 2.7600 - val_y1_output_loss: 0.5432 - val_y2_output_loss: 2.1872 - val_y1_output_root_mean_squared_error: 0.7251 - val_y2_output_root_mean_squared_error: 1.4947
# Epoch 106/500
# 614/614 [==============================] - 0s 119us/sample - loss: 2.1915 - y1_output_loss: 0.5411 - y2_output_loss: 1.6741 - y1_output_root_mean_squared_error: 0.7364 - y2_output_root_mean_squared_error: 1.2842 - val_loss: 8.5739 - val_y1_output_loss: 1.7467 - val_y2_output_loss: 6.7051 - val_y1_output_root_mean_squared_error: 1.3379 - val_y2_output_root_mean_squared_error: 2.6046
# Epoch 107/500
# 614/614 [==============================] - 0s 118us/sample - loss: 3.4549 - y1_output_loss: 0.9728 - y2_output_loss: 2.5021 - y1_output_root_mean_squared_error: 0.9817 - y2_output_root_mean_squared_error: 1.5783 - val_loss: 10.2723 - val_y1_output_loss: 3.1177 - val_y2_output_loss: 7.0550 - val_y1_output_root_mean_squared_error: 1.7915 - val_y2_output_root_mean_squared_error: 2.6576
# Epoch 108/500
# 614/614 [==============================] - 0s 120us/sample - loss: 3.2463 - y1_output_loss: 0.7702 - y2_output_loss: 2.5350 - y1_output_root_mean_squared_error: 0.8814 - y2_output_root_mean_squared_error: 1.5715 - val_loss: 10.4794 - val_y1_output_loss: 1.4754 - val_y2_output_loss: 8.8992 - val_y1_output_root_mean_squared_error: 1.2277 - val_y2_output_root_mean_squared_error: 2.9954
# Epoch 109/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.6065 - y1_output_loss: 0.5679 - y2_output_loss: 2.0160 - y1_output_root_mean_squared_error: 0.7570 - y2_output_root_mean_squared_error: 1.4260 - val_loss: 2.3075 - val_y1_output_loss: 0.5418 - val_y2_output_loss: 1.7435 - val_y1_output_root_mean_squared_error: 0.7211 - val_y2_output_root_mean_squared_error: 1.3369
# Epoch 110/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.2954 - y1_output_loss: 1.0461 - y2_output_loss: 3.2180 - y1_output_root_mean_squared_error: 1.0275 - y2_output_root_mean_squared_error: 1.7999 - val_loss: 3.0976 - val_y1_output_loss: 0.7599 - val_y2_output_loss: 2.2952 - val_y1_output_root_mean_squared_error: 0.8721 - val_y2_output_root_mean_squared_error: 1.5287
# Epoch 111/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.2924 - y1_output_loss: 0.7144 - y2_output_loss: 2.5623 - y1_output_root_mean_squared_error: 0.8440 - y2_output_root_mean_squared_error: 1.6062 - val_loss: 2.5098 - val_y1_output_loss: 0.4612 - val_y2_output_loss: 2.0091 - val_y1_output_root_mean_squared_error: 0.6676 - val_y2_output_root_mean_squared_error: 1.4367
# Epoch 112/500
# 614/614 [==============================] - 0s 121us/sample - loss: 3.6975 - y1_output_loss: 0.8462 - y2_output_loss: 2.8172 - y1_output_root_mean_squared_error: 0.9242 - y2_output_root_mean_squared_error: 1.6862 - val_loss: 2.8440 - val_y1_output_loss: 0.7237 - val_y2_output_loss: 2.0751 - val_y1_output_root_mean_squared_error: 0.8459 - val_y2_output_root_mean_squared_error: 1.4589
# Epoch 113/500
# 614/614 [==============================] - 0s 119us/sample - loss: 2.6808 - y1_output_loss: 0.6600 - y2_output_loss: 2.0052 - y1_output_root_mean_squared_error: 0.8142 - y2_output_root_mean_squared_error: 1.4205 - val_loss: 2.5351 - val_y1_output_loss: 0.5378 - val_y2_output_loss: 1.9516 - val_y1_output_root_mean_squared_error: 0.7271 - val_y2_output_root_mean_squared_error: 1.4165
# Epoch 114/500
# 614/614 [==============================] - 0s 119us/sample - loss: 3.5964 - y1_output_loss: 0.8287 - y2_output_loss: 2.7369 - y1_output_root_mean_squared_error: 0.9134 - y2_output_root_mean_squared_error: 1.6619 - val_loss: 2.8213 - val_y1_output_loss: 0.7077 - val_y2_output_loss: 2.0970 - val_y1_output_root_mean_squared_error: 0.8124 - val_y2_output_root_mean_squared_error: 1.4701
# Epoch 115/500
# 614/614 [==============================] - 0s 120us/sample - loss: 2.3967 - y1_output_loss: 0.5239 - y2_output_loss: 1.8619 - y1_output_root_mean_squared_error: 0.7248 - y2_output_root_mean_squared_error: 1.3680 - val_loss: 2.6677 - val_y1_output_loss: 0.5742 - val_y2_output_loss: 2.0649 - val_y1_output_root_mean_squared_error: 0.7473 - val_y2_output_root_mean_squared_error: 1.4523
# Epoch 116/500
# 614/614 [==============================] - 0s 121us/sample - loss: 4.2451 - y1_output_loss: 1.2283 - y2_output_loss: 3.0089 - y1_output_root_mean_squared_error: 1.1107 - y2_output_root_mean_squared_error: 1.7353 - val_loss: 5.4459 - val_y1_output_loss: 0.4695 - val_y2_output_loss: 4.9738 - val_y1_output_root_mean_squared_error: 0.6862 - val_y2_output_root_mean_squared_error: 2.2305
# Epoch 117/500
# 614/614 [==============================] - 0s 120us/sample - loss: 3.2750 - y1_output_loss: 0.7670 - y2_output_loss: 2.4829 - y1_output_root_mean_squared_error: 0.8790 - y2_output_root_mean_squared_error: 1.5819 - val_loss: 2.8608 - val_y1_output_loss: 0.6881 - val_y2_output_loss: 2.1827 - val_y1_output_root_mean_squared_error: 0.8201 - val_y2_output_root_mean_squared_error: 1.4793
# Epoch 118/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.3284 - y1_output_loss: 0.5423 - y2_output_loss: 1.7969 - y1_output_root_mean_squared_error: 0.7342 - y2_output_root_mean_squared_error: 1.3376 - val_loss: 5.1318 - val_y1_output_loss: 0.4399 - val_y2_output_loss: 4.7018 - val_y1_output_root_mean_squared_error: 0.6582 - val_y2_output_root_mean_squared_error: 2.1676
# Epoch 119/500
# 614/614 [==============================] - 0s 118us/sample - loss: 4.8292 - y1_output_loss: 1.2419 - y2_output_loss: 3.5510 - y1_output_root_mean_squared_error: 1.1170 - y2_output_root_mean_squared_error: 1.8925 - val_loss: 2.4786 - val_y1_output_loss: 0.4939 - val_y2_output_loss: 1.9566 - val_y1_output_root_mean_squared_error: 0.7032 - val_y2_output_root_mean_squared_error: 1.4086
# Epoch 120/500
# 614/614 [==============================] - 0s 118us/sample - loss: 3.1603 - y1_output_loss: 0.7782 - y2_output_loss: 2.3531 - y1_output_root_mean_squared_error: 0.8862 - y2_output_root_mean_squared_error: 1.5411 - val_loss: 2.4620 - val_y1_output_loss: 0.6389 - val_y2_output_loss: 1.8036 - val_y1_output_root_mean_squared_error: 0.7845 - val_y2_output_root_mean_squared_error: 1.3589
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 120us/sample - loss: 0.3608 - y1_output_loss: 0.1227 - y2_output_loss: 0.2358 - y1_output_root_mean_squared_error: 0.3513 - y2_output_root_mean_squared_error: 0.4872 - val_loss: 0.7519 - val_y1_output_loss: 0.1385 - val_y2_output_loss: 0.5923 - val_y1_output_root_mean_squared_error: 0.3721 - val_y2_output_root_mean_squared_error: 0.7832
# Epoch 462/500
# 614/614 [==============================] - 0s 119us/sample - loss: 0.4391 - y1_output_loss: 0.1238 - y2_output_loss: 0.3131 - y1_output_root_mean_squared_error: 0.3521 - y2_output_root_mean_squared_error: 0.5614 - val_loss: 0.7732 - val_y1_output_loss: 0.1942 - val_y2_output_loss: 0.5686 - val_y1_output_root_mean_squared_error: 0.4387 - val_y2_output_root_mean_squared_error: 0.7620
# Epoch 463/500
# 614/614 [==============================] - 0s 117us/sample - loss: 0.7432 - y1_output_loss: 0.2423 - y2_output_loss: 0.4954 - y1_output_root_mean_squared_error: 0.4939 - y2_output_root_mean_squared_error: 0.7066 - val_loss: 0.7579 - val_y1_output_loss: 0.1422 - val_y2_output_loss: 0.6067 - val_y1_output_root_mean_squared_error: 0.3760 - val_y2_output_root_mean_squared_error: 0.7852
# Epoch 464/500
# 614/614 [==============================] - 0s 117us/sample - loss: 0.3648 - y1_output_loss: 0.1185 - y2_output_loss: 0.2475 - y1_output_root_mean_squared_error: 0.3450 - y2_output_root_mean_squared_error: 0.4958 - val_loss: 0.8749 - val_y1_output_loss: 0.1586 - val_y2_output_loss: 0.7028 - val_y1_output_root_mean_squared_error: 0.3965 - val_y2_output_root_mean_squared_error: 0.8472
# Epoch 465/500
# 614/614 [==============================] - 0s 115us/sample - loss: 0.3998 - y1_output_loss: 0.1197 - y2_output_loss: 0.2782 - y1_output_root_mean_squared_error: 0.3455 - y2_output_root_mean_squared_error: 0.5295 - val_loss: 0.8036 - val_y1_output_loss: 0.2029 - val_y2_output_loss: 0.5924 - val_y1_output_root_mean_squared_error: 0.4473 - val_y2_output_root_mean_squared_error: 0.7769
# Epoch 466/500
# 614/614 [==============================] - 0s 118us/sample - loss: 0.3884 - y1_output_loss: 0.1315 - y2_output_loss: 0.2612 - y1_output_root_mean_squared_error: 0.3607 - y2_output_root_mean_squared_error: 0.5082 - val_loss: 3.2744 - val_y1_output_loss: 1.0512 - val_y2_output_loss: 2.1442 - val_y1_output_root_mean_squared_error: 1.0343 - val_y2_output_root_mean_squared_error: 1.4848
# Epoch 467/500
# 614/614 [==============================] - 0s 118us/sample - loss: 1.3943 - y1_output_loss: 0.3213 - y2_output_loss: 1.0622 - y1_output_root_mean_squared_error: 0.5694 - y2_output_root_mean_squared_error: 1.0345 - val_loss: 0.8542 - val_y1_output_loss: 0.1535 - val_y2_output_loss: 0.6865 - val_y1_output_root_mean_squared_error: 0.3891 - val_y2_output_root_mean_squared_error: 0.8384
# Epoch 468/500
# 614/614 [==============================] - 0s 116us/sample - loss: 0.5144 - y1_output_loss: 0.1503 - y2_output_loss: 0.3613 - y1_output_root_mean_squared_error: 0.3890 - y2_output_root_mean_squared_error: 0.6025 - val_loss: 0.7618 - val_y1_output_loss: 0.1539 - val_y2_output_loss: 0.5887 - val_y1_output_root_mean_squared_error: 0.3926 - val_y2_output_root_mean_squared_error: 0.7795
# Epoch 469/500
# 614/614 [==============================] - 0s 118us/sample - loss: 0.5550 - y1_output_loss: 0.1592 - y2_output_loss: 0.3970 - y1_output_root_mean_squared_error: 0.3982 - y2_output_root_mean_squared_error: 0.6296 - val_loss: 1.0143 - val_y1_output_loss: 0.1753 - val_y2_output_loss: 0.8232 - val_y1_output_root_mean_squared_error: 0.4179 - val_y2_output_root_mean_squared_error: 0.9163
# Epoch 470/500
# 614/614 [==============================] - 0s 121us/sample - loss: 0.4176 - y1_output_loss: 0.1284 - y2_output_loss: 0.2861 - y1_output_root_mean_squared_error: 0.3592 - y2_output_root_mean_squared_error: 0.5372 - val_loss: 0.9477 - val_y1_output_loss: 0.2035 - val_y2_output_loss: 0.7426 - val_y1_output_root_mean_squared_error: 0.4453 - val_y2_output_root_mean_squared_error: 0.8657
# Epoch 471/500
# 614/614 [==============================] - 0s 119us/sample - loss: 0.4801 - y1_output_loss: 0.1337 - y2_output_loss: 0.3440 - y1_output_root_mean_squared_error: 0.3667 - y2_output_root_mean_squared_error: 0.5879 - val_loss: 0.9310 - val_y1_output_loss: 0.2091 - val_y2_output_loss: 0.7059 - val_y1_output_root_mean_squared_error: 0.4580 - val_y2_output_root_mean_squared_error: 0.8493
# Epoch 472/500
# 614/614 [==============================] - 0s 118us/sample - loss: 0.4919 - y1_output_loss: 0.1477 - y2_output_loss: 0.3401 - y1_output_root_mean_squared_error: 0.3856 - y2_output_root_mean_squared_error: 0.5858 - val_loss: 1.0173 - val_y1_output_loss: 0.1912 - val_y2_output_loss: 0.8036 - val_y1_output_root_mean_squared_error: 0.4403 - val_y2_output_root_mean_squared_error: 0.9074
# Epoch 473/500
# 614/614 [==============================] - 0s 119us/sample - loss: 0.5638 - y1_output_loss: 0.1414 - y2_output_loss: 0.4210 - y1_output_root_mean_squared_error: 0.3769 - y2_output_root_mean_squared_error: 0.6494 - val_loss: 0.8901 - val_y1_output_loss: 0.2448 - val_y2_output_loss: 0.6322 - val_y1_output_root_mean_squared_error: 0.4931 - val_y2_output_root_mean_squared_error: 0.8043
# Epoch 474/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.5800 - y1_output_loss: 0.1792 - y2_output_loss: 0.3968 - y1_output_root_mean_squared_error: 0.4248 - y2_output_root_mean_squared_error: 0.6321 - val_loss: 0.7747 - val_y1_output_loss: 0.1679 - val_y2_output_loss: 0.5992 - val_y1_output_root_mean_squared_error: 0.4074 - val_y2_output_root_mean_squared_error: 0.7802
# Epoch 475/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3468 - y1_output_loss: 0.1207 - y2_output_loss: 0.2252 - y1_output_root_mean_squared_error: 0.3484 - y2_output_root_mean_squared_error: 0.4747 - val_loss: 0.7677 - val_y1_output_loss: 0.1393 - val_y2_output_loss: 0.6119 - val_y1_output_root_mean_squared_error: 0.3729 - val_y2_output_root_mean_squared_error: 0.7929
# Epoch 476/500
# 614/614 [==============================] - 0s 118us/sample - loss: 0.3820 - y1_output_loss: 0.1183 - y2_output_loss: 0.2621 - y1_output_root_mean_squared_error: 0.3446 - y2_output_root_mean_squared_error: 0.5130 - val_loss: 0.8659 - val_y1_output_loss: 0.1825 - val_y2_output_loss: 0.6703 - val_y1_output_root_mean_squared_error: 0.4258 - val_y2_output_root_mean_squared_error: 0.8274
# Epoch 477/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.4602 - y1_output_loss: 0.1412 - y2_output_loss: 0.3160 - y1_output_root_mean_squared_error: 0.3764 - y2_output_root_mean_squared_error: 0.5643 - val_loss: 0.6504 - val_y1_output_loss: 0.1386 - val_y2_output_loss: 0.5001 - val_y1_output_root_mean_squared_error: 0.3717 - val_y2_output_root_mean_squared_error: 0.7157
# Epoch 478/500
# 614/614 [==============================] - 0s 117us/sample - loss: 0.4081 - y1_output_loss: 0.1295 - y2_output_loss: 0.2767 - y1_output_root_mean_squared_error: 0.3613 - y2_output_root_mean_squared_error: 0.5268 - val_loss: 0.7235 - val_y1_output_loss: 0.1400 - val_y2_output_loss: 0.5668 - val_y1_output_root_mean_squared_error: 0.3745 - val_y2_output_root_mean_squared_error: 0.7637
# Epoch 479/500
# 614/614 [==============================] - 0s 116us/sample - loss: 0.5254 - y1_output_loss: 0.1530 - y2_output_loss: 0.3678 - y1_output_root_mean_squared_error: 0.3927 - y2_output_root_mean_squared_error: 0.6092 - val_loss: 0.8215 - val_y1_output_loss: 0.2024 - val_y2_output_loss: 0.5944 - val_y1_output_root_mean_squared_error: 0.4550 - val_y2_output_root_mean_squared_error: 0.7839
# Epoch 480/500
# 614/614 [==============================] - 0s 117us/sample - loss: 0.4424 - y1_output_loss: 0.1455 - y2_output_loss: 0.2978 - y1_output_root_mean_squared_error: 0.3815 - y2_output_root_mean_squared_error: 0.5449 - val_loss: 0.9045 - val_y1_output_loss: 0.2359 - val_y2_output_loss: 0.6550 - val_y1_output_root_mean_squared_error: 0.4840 - val_y2_output_root_mean_squared_error: 0.8187
# Epoch 481/500
# 614/614 [==============================] - 0s 117us/sample - loss: 0.7115 - y1_output_loss: 0.1889 - y2_output_loss: 0.5181 - y1_output_root_mean_squared_error: 0.4355 - y2_output_root_mean_squared_error: 0.7224 - val_loss: 1.0685 - val_y1_output_loss: 0.3613 - val_y2_output_loss: 0.6903 - val_y1_output_root_mean_squared_error: 0.6034 - val_y2_output_root_mean_squared_error: 0.8393
# Epoch 482/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3168 - y1_output_loss: 0.1137 - y2_output_loss: 0.2031 - y1_output_root_mean_squared_error: 0.3381 - y2_output_root_mean_squared_error: 0.4500 - val_loss: 1.1636 - val_y1_output_loss: 0.2577 - val_y2_output_loss: 0.8789 - val_y1_output_root_mean_squared_error: 0.5118 - val_y2_output_root_mean_squared_error: 0.9496
# Epoch 483/500
# 614/614 [==============================] - 0s 119us/sample - loss: 0.3843 - y1_output_loss: 0.1119 - y2_output_loss: 0.2721 - y1_output_root_mean_squared_error: 0.3348 - y2_output_root_mean_squared_error: 0.5217 - val_loss: 0.9982 - val_y1_output_loss: 0.1670 - val_y2_output_loss: 0.8050 - val_y1_output_root_mean_squared_error: 0.4120 - val_y2_output_root_mean_squared_error: 0.9102
# Epoch 484/500
# 614/614 [==============================] - 0s 118us/sample - loss: 0.3514 - y1_output_loss: 0.1146 - y2_output_loss: 0.2352 - y1_output_root_mean_squared_error: 0.3384 - y2_output_root_mean_squared_error: 0.4868 - val_loss: 0.7164 - val_y1_output_loss: 0.1465 - val_y2_output_loss: 0.5496 - val_y1_output_root_mean_squared_error: 0.3873 - val_y2_output_root_mean_squared_error: 0.7526
# Epoch 485/500
# 614/614 [==============================] - 0s 118us/sample - loss: 0.3273 - y1_output_loss: 0.1185 - y2_output_loss: 0.2067 - y1_output_root_mean_squared_error: 0.3452 - y2_output_root_mean_squared_error: 0.4562 - val_loss: 0.7034 - val_y1_output_loss: 0.1337 - val_y2_output_loss: 0.5509 - val_y1_output_root_mean_squared_error: 0.3688 - val_y2_output_root_mean_squared_error: 0.7533
# Epoch 486/500
# 614/614 [==============================] - 0s 121us/sample - loss: 0.4099 - y1_output_loss: 0.1275 - y2_output_loss: 0.2806 - y1_output_root_mean_squared_error: 0.3579 - y2_output_root_mean_squared_error: 0.5308 - val_loss: 0.9371 - val_y1_output_loss: 0.2303 - val_y2_output_loss: 0.6827 - val_y1_output_root_mean_squared_error: 0.4843 - val_y2_output_root_mean_squared_error: 0.8381
# Epoch 487/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4781 - y1_output_loss: 0.1519 - y2_output_loss: 0.3278 - y1_output_root_mean_squared_error: 0.3889 - y2_output_root_mean_squared_error: 0.5717 - val_loss: 1.2535 - val_y1_output_loss: 0.2788 - val_y2_output_loss: 0.9832 - val_y1_output_root_mean_squared_error: 0.5185 - val_y2_output_root_mean_squared_error: 0.9923
# Epoch 488/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.5574 - y1_output_loss: 0.1617 - y2_output_loss: 0.3929 - y1_output_root_mean_squared_error: 0.4032 - y2_output_root_mean_squared_error: 0.6283 - val_loss: 0.9190 - val_y1_output_loss: 0.1950 - val_y2_output_loss: 0.7136 - val_y1_output_root_mean_squared_error: 0.4368 - val_y2_output_root_mean_squared_error: 0.8533
# Epoch 489/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4174 - y1_output_loss: 0.1454 - y2_output_loss: 0.2747 - y1_output_root_mean_squared_error: 0.3787 - y2_output_root_mean_squared_error: 0.5234 - val_loss: 1.0420 - val_y1_output_loss: 0.4307 - val_y2_output_loss: 0.5893 - val_y1_output_root_mean_squared_error: 0.6601 - val_y2_output_root_mean_squared_error: 0.7786
# Epoch 490/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3602 - y1_output_loss: 0.1279 - y2_output_loss: 0.2301 - y1_output_root_mean_squared_error: 0.3591 - y2_output_root_mean_squared_error: 0.4809 - val_loss: 0.9107 - val_y1_output_loss: 0.1871 - val_y2_output_loss: 0.7133 - val_y1_output_root_mean_squared_error: 0.4310 - val_y2_output_root_mean_squared_error: 0.8514
# Epoch 491/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4352 - y1_output_loss: 0.1404 - y2_output_loss: 0.2931 - y1_output_root_mean_squared_error: 0.3761 - y2_output_root_mean_squared_error: 0.5420 - val_loss: 1.2258 - val_y1_output_loss: 0.2662 - val_y2_output_loss: 0.9227 - val_y1_output_root_mean_squared_error: 0.5237 - val_y2_output_root_mean_squared_error: 0.9755
# Epoch 492/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3713 - y1_output_loss: 0.1163 - y2_output_loss: 0.2563 - y1_output_root_mean_squared_error: 0.3419 - y2_output_root_mean_squared_error: 0.5044 - val_loss: 0.7933 - val_y1_output_loss: 0.1642 - val_y2_output_loss: 0.6117 - val_y1_output_root_mean_squared_error: 0.4049 - val_y2_output_root_mean_squared_error: 0.7933
# Epoch 493/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3806 - y1_output_loss: 0.1265 - y2_output_loss: 0.2509 - y1_output_root_mean_squared_error: 0.3572 - y2_output_root_mean_squared_error: 0.5030 - val_loss: 0.7754 - val_y1_output_loss: 0.1827 - val_y2_output_loss: 0.5829 - val_y1_output_root_mean_squared_error: 0.4257 - val_y2_output_root_mean_squared_error: 0.7708
# Epoch 494/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3587 - y1_output_loss: 0.1194 - y2_output_loss: 0.2392 - y1_output_root_mean_squared_error: 0.3459 - y2_output_root_mean_squared_error: 0.4889 - val_loss: 1.4243 - val_y1_output_loss: 0.3409 - val_y2_output_loss: 1.0551 - val_y1_output_root_mean_squared_error: 0.5859 - val_y2_output_root_mean_squared_error: 1.0397
# Epoch 495/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3664 - y1_output_loss: 0.1239 - y2_output_loss: 0.2443 - y1_output_root_mean_squared_error: 0.3527 - y2_output_root_mean_squared_error: 0.4920 - val_loss: 1.0442 - val_y1_output_loss: 0.1597 - val_y2_output_loss: 0.8606 - val_y1_output_root_mean_squared_error: 0.4011 - val_y2_output_root_mean_squared_error: 0.9399
# Epoch 496/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3446 - y1_output_loss: 0.1100 - y2_output_loss: 0.2338 - y1_output_root_mean_squared_error: 0.3318 - y2_output_root_mean_squared_error: 0.4842 - val_loss: 0.9019 - val_y1_output_loss: 0.2130 - val_y2_output_loss: 0.6647 - val_y1_output_root_mean_squared_error: 0.4641 - val_y2_output_root_mean_squared_error: 0.8286
# Epoch 497/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3676 - y1_output_loss: 0.1222 - y2_output_loss: 0.2426 - y1_output_root_mean_squared_error: 0.3510 - y2_output_root_mean_squared_error: 0.4943 - val_loss: 1.0949 - val_y1_output_loss: 0.2012 - val_y2_output_loss: 0.8850 - val_y1_output_root_mean_squared_error: 0.4472 - val_y2_output_root_mean_squared_error: 0.9460
# Epoch 498/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4032 - y1_output_loss: 0.1303 - y2_output_loss: 0.2720 - y1_output_root_mean_squared_error: 0.3616 - y2_output_root_mean_squared_error: 0.5220 - val_loss: 1.0520 - val_y1_output_loss: 0.2530 - val_y2_output_loss: 0.7673 - val_y1_output_root_mean_squared_error: 0.5099 - val_y2_output_root_mean_squared_error: 0.8899
# Epoch 499/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3745 - y1_output_loss: 0.1339 - y2_output_loss: 0.2391 - y1_output_root_mean_squared_error: 0.3672 - y2_output_root_mean_squared_error: 0.4896 - val_loss: 0.9808 - val_y1_output_loss: 0.1670 - val_y2_output_loss: 0.7994 - val_y1_output_root_mean_squared_error: 0.4084 - val_y2_output_root_mean_squared_error: 0.9022
# Epoch 500/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4025 - y1_output_loss: 0.1208 - y2_output_loss: 0.2781 - y1_output_root_mean_squared_error: 0.3489 - y2_output_root_mean_squared_error: 0.5299 - val_loss: 0.6655 - val_y1_output_loss: 0.1398 - val_y2_output_loss: 0.5175 - val_y1_output_root_mean_squared_error: 0.3740 - val_y2_output_root_mean_squared_error: 0.7250

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 386us/sample - loss: 0.6655 - y1_output_loss: 0.1426 - y2_output_loss: 0.5196 - y1_output_root_mean_squared_error: 0.3740 - y2_output_root_mean_squared_error: 0.7250
# Loss = 0.6655102867584723, Y1_loss = 0.1425594538450241, Y1_mse = 0.37401193380355835, Y2_loss = 0.519636332988739, Y2_mse = 0.725000262260437

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
